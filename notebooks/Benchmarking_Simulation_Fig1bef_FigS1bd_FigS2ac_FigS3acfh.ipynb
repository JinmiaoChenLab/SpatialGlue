# %% [markdown]
# # Benchmarking on simulation data

# %% [markdown]
# This notebook aims to reproduce the benchmarking results on simulation data, including qualitative and quantitative results. The experimental results are avaible at https://drive.google.com/drive/u/0/folders/1HWdVjYvQ9jDQnjcheAMN6qndXiHRPnWs.

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = 'Simulation1'
path = '../result/'
adata = sc.read_h5ad(path + dataset + '/' + 'adata_all_simulation1.h5ad')
# Out:
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
# simulation1
list_mod1 = [2,3,4,5,1]
adata.obs['RNA_label_origi']  = pd.Categorical(adata.obs['RNA_label_origi'], 
                      categories=list_mod1,
                      ordered=True)
list_mod2 = [2,1,3,4,5]
adata.obs['Pro_label_origi']  = pd.Categorical(adata.obs['Pro_label_origi'], 
                      categories=list_mod2,
                      ordered=True)
list_Seurat = [4,1,2,0,3]
adata.obs['Seurat']  = pd.Categorical(adata.obs['Seurat'], 
                      categories=list_Seurat,
                      ordered=True)
list_totalVI = [1,2,4,3,5]
adata.obs['totalVI']  = pd.Categorical(adata.obs['totalVI'], 
                      categories=list_totalVI,
                      ordered=True)
list_MultiVI = ['3','2','1','4','0']
adata.obs['MultiVI']  = pd.Categorical(adata.obs['MultiVI'], 
                      categories=list_MultiVI,
                      ordered=True)
list_MOFA = [3,1,2,4,5]
adata.obs['MOFA']  = pd.Categorical(adata.obs['MOFA'], 
                      categories=list_MOFA,
                      ordered=True)
list_MEFISTO = [4,2,1,5,3]
adata.obs['MEFISTO']  = pd.Categorical(adata.obs['MEFISTO'], 
                      categories=list_MEFISTO,
                      ordered=True)
list_scMM = [2,3,4,1,5]
adata.obs['scMM']  = pd.Categorical(adata.obs['scMM'], 
                      categories=list_scMM,
                      ordered=True)
list_StabMap = ['0','3','4','1','2']
adata.obs['StabMap']  = pd.Categorical(adata.obs['StabMap'], 
                      categories=list_StabMap,
                      ordered=True)

list_SpatialGlue = [2,1,3,4,5]
adata.obs['SpatialGlue']  = pd.Categorical(adata.obs['SpatialGlue'], 
                      categories=list_SpatialGlue,
                      ordered=True)

# %%
# simulation2
list_mod1 = [4,5,3,1,2]
adata.obs['RNA_label_origi']  = pd.Categorical(adata.obs['RNA_label_origi'], 
                      categories=list_mod1,
                      ordered=True)
list_mod2 = [2,1,3,4,5]
adata.obs['Pro_label_origi']  = pd.Categorical(adata.obs['Pro_label_origi'], 
                      categories=list_mod2,
                      ordered=True)
list_Seurat = [2,0,1,3,4]
adata.obs['Seurat']  = pd.Categorical(adata.obs['Seurat'], 
                      categories=list_Seurat,
                      ordered=True)
list_totalVI = [2,3,4,1,5]
adata.obs['totalVI']  = pd.Categorical(adata.obs['totalVI'], 
                      categories=list_totalVI,
                      ordered=True)
list_MultiVI = ['1','2','0','3','4']
adata.obs['MultiVI']  = pd.Categorical(adata.obs['MultiVI'], 
                      categories=list_MultiVI,
                      ordered=True)
list_MOFA = [5,2,1,4,3]
adata.obs['MOFA']  = pd.Categorical(adata.obs['MOFA'], 
                      categories=list_MOFA,
                      ordered=True)
list_MEFISTO = [3,1,4,2,5]
adata.obs['MEFISTO']  = pd.Categorical(adata.obs['MEFISTO'], 
                      categories=list_MEFISTO,
                      ordered=True)
list_scMM = [2,3,1,4,5]
adata.obs['scMM']  = pd.Categorical(adata.obs['scMM'], 
                      categories=list_scMM,
                      ordered=True)
list_StabMap = ['3','4','0','2','1']
adata.obs['StabMap']  = pd.Categorical(adata.obs['StabMap'], 
                      categories=list_StabMap,
                      ordered=True)

list_SpatialGlue = [2,3,4,5,1]
adata.obs['SpatialGlue']  = pd.Categorical(adata.obs['SpatialGlue'], 
                      categories=list_SpatialGlue,
                      ordered=True)

# %%
# simulation3
list_mod1 = [4,5,3,1,2]
adata.obs['RNA_label_origi']  = pd.Categorical(adata.obs['RNA_label_origi'], 
                      categories=list_mod1,
                      ordered=True)
list_mod2 = [2,1,3,4,5]
adata.obs['Pro_label_origi']  = pd.Categorical(adata.obs['Pro_label_origi'], 
                      categories=list_mod2,
                      ordered=True)
list_Seurat = [2,0,1,3,4]
adata.obs['Seurat']  = pd.Categorical(adata.obs['Seurat'], 
                      categories=list_Seurat,
                      ordered=True)
list_totalVI = [2,3,4,1,5]
adata.obs['totalVI']  = pd.Categorical(adata.obs['totalVI'], 
                      categories=list_totalVI,
                      ordered=True)
list_MultiVI = ['1','2','0','3','4']
adata.obs['MultiVI']  = pd.Categorical(adata.obs['MultiVI'], 
                      categories=list_MultiVI,
                      ordered=True)
list_MOFA = [5,2,1,4,3]
adata.obs['MOFA']  = pd.Categorical(adata.obs['MOFA'], 
                      categories=list_MOFA,
                      ordered=True)
list_MEFISTO = [3,1,4,2,5]
adata.obs['MEFISTO']  = pd.Categorical(adata.obs['MEFISTO'], 
                      categories=list_MEFISTO,
                      ordered=True)
list_scMM = [2,3,1,4,5]
adata.obs['scMM']  = pd.Categorical(adata.obs['scMM'], 
                      categories=list_scMM,
                      ordered=True)
list_StabMap = ['3','4','0','2','1']
adata.obs['StabMap']  = pd.Categorical(adata.obs['StabMap'], 
                      categories=list_StabMap,
                      ordered=True)

list_SpatialGlue = [2,3,4,5,1]
adata.obs['SpatialGlue']  = pd.Categorical(adata.obs['SpatialGlue'], 
                      categories=list_SpatialGlue,
                      ordered=True)

# %%
# simulation4
list_mod1 = [2,3,4,5,1]
adata.obs['RNA_label_origi']  = pd.Categorical(adata.obs['RNA_label_origi'], 
                      categories=list_mod1,
                      ordered=True)
list_mod2 = [2,3,4,1,5]
adata.obs['Pro_label_origi']  = pd.Categorical(adata.obs['Pro_label_origi'], 
                      categories=list_mod2,
                      ordered=True)
list_Seurat = [0,1,2,3,4]
adata.obs['Seurat']  = pd.Categorical(adata.obs['Seurat'], 
                      categories=list_Seurat,
                      ordered=True)
list_totalVI = [2,3,4,1,5]
adata.obs['totalVI']  = pd.Categorical(adata.obs['totalVI'], 
                      categories=list_totalVI,
                      ordered=True)
list_MultiVI = ['4','3','1','0','2']
adata.obs['MultiVI']  = pd.Categorical(adata.obs['MultiVI'], 
                      categories=list_MultiVI,
                      ordered=True)
list_MOFA = [1,5,2,3,4]
adata.obs['MOFA']  = pd.Categorical(adata.obs['MOFA'], 
                      categories=list_MOFA,
                      ordered=True)
list_MEFISTO = [3,1,4,2,5]
adata.obs['MEFISTO']  = pd.Categorical(adata.obs['MEFISTO'], 
                      categories=list_MEFISTO,
                      ordered=True)
list_scMM = [2,1,3,4,5]
adata.obs['scMM']  = pd.Categorical(adata.obs['scMM'], 
                      categories=list_scMM,
                      ordered=True)
list_StabMap = ['4','2','1','3','0']
adata.obs['StabMap']  = pd.Categorical(adata.obs['StabMap'], 
                      categories=list_StabMap,
                      ordered=True)

list_SpatialGlue = [2,3,4,5,1]
adata.obs['SpatialGlue']  = pd.Categorical(adata.obs['SpatialGlue'], 
                      categories=list_SpatialGlue,
                      ordered=True)

# %%
# simulation5
list_mod1 = [2,3,4,1,5]
adata.obs['RNA_label_origi']  = pd.Categorical(adata.obs['RNA_label_origi'], 
                      categories=list_mod1,
                      ordered=True)
list_mod2 = [2,1,3,4,5]
adata.obs['Pro_label_origi']  = pd.Categorical(adata.obs['Pro_label_origi'], 
                      categories=list_mod2,
                      ordered=True)
list_Seurat = [0,1,2,3,4]
adata.obs['Seurat']  = pd.Categorical(adata.obs['Seurat'], 
                      categories=list_Seurat,
                      ordered=True)
list_totalVI = [2,3,4,1,5]
adata.obs['totalVI']  = pd.Categorical(adata.obs['totalVI'], 
                      categories=list_totalVI,
                      ordered=True)
list_MultiVI = ['4','2','3','0','1']
adata.obs['MultiVI']  = pd.Categorical(adata.obs['MultiVI'], 
                      categories=list_MultiVI,
                      ordered=True)
list_MOFA = [1,4,2,3,5]
adata.obs['MOFA']  = pd.Categorical(adata.obs['MOFA'], 
                      categories=list_MOFA,
                      ordered=True)
list_MEFISTO = [5,1,4,2,3]
adata.obs['MEFISTO']  = pd.Categorical(adata.obs['MEFISTO'], 
                      categories=list_MEFISTO,
                      ordered=True)
list_scMM = [2,1,3,4,5]
adata.obs['scMM']  = pd.Categorical(adata.obs['scMM'], 
                      categories=list_scMM,
                      ordered=True)
list_StabMap = ['3','2','1','4','0']
adata.obs['StabMap']  = pd.Categorical(adata.obs['StabMap'], 
                      categories=list_StabMap,
                      ordered=True)

list_SpatialGlue = [2,1,3,4,5]
adata.obs['SpatialGlue']  = pd.Categorical(adata.obs['SpatialGlue'], 
                      categories=list_SpatialGlue,
                      ordered=True)

# %%
#plt.rcParams['figure.figsize'] = (8,8)
plt.rcParams['font.size'] = 10
plt.rcParams['font.sans-serif'] = 'Arial'

fig, ax_list = plt.subplots(2,5, figsize=(8,4)) #8,4
s_size = 40
sc.pl.embedding(adata, basis='spatial', color='RNA_label_origi', title='Modality 1', ax=ax_list[0,0],s=s_size, show=False)
sc.pl.embedding(adata, basis='spatial', color='Seurat', ax=ax_list[0,1],s=s_size, show=False)
sc.pl.embedding(adata, basis='spatial', color='totalVI', ax=ax_list[0,2], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='MultiVI', ax=ax_list[0,3], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='MOFA', title='MOFA+', ax=ax_list[0,4], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='Pro_label_origi', title='Modality 2', ax=ax_list[1,0],s=s_size, show=False)
sc.pl.embedding(adata, basis='spatial', color='MEFISTO', ax=ax_list[1,1], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='scMM', ax=ax_list[1,2], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='StabMap', ax=ax_list[1,3], s=s_size,show=False)
sc.pl.embedding(adata, basis='spatial', color='SpatialGlue', ax=ax_list[1,4], s=s_size,show=False)

# remove legend
ax_list[0,0].get_legend().remove()
ax_list[0,1].get_legend().remove()
ax_list[0,2].get_legend().remove()
ax_list[0,3].get_legend().remove()
ax_list[0,4].get_legend().remove()
ax_list[1,0].get_legend().remove()
ax_list[1,1].get_legend().remove()
ax_list[1,2].get_legend().remove()
ax_list[1,3].get_legend().remove()
#ax_list[1,4].get_legend().remove()

# remove x, y axis
ax_list[0, 0].set_xlabel('')
ax_list[0, 1].set_xlabel('')
ax_list[0, 2].set_xlabel('')
ax_list[0, 3].set_xlabel('')
ax_list[0, 4].set_xlabel('')
ax_list[1, 0].set_xlabel('')
ax_list[1, 1].set_xlabel('')
ax_list[1, 2].set_xlabel('')
ax_list[1, 3].set_xlabel('')
ax_list[1, 4].set_xlabel('')

ax_list[0, 0].set_ylabel('')
ax_list[0, 1].set_ylabel('')
ax_list[0, 2].set_ylabel('')
ax_list[0, 3].set_ylabel('')
ax_list[0, 4].set_ylabel('')
ax_list[1, 0].set_ylabel('')
ax_list[1, 1].set_ylabel('')
ax_list[1, 2].set_ylabel('')
ax_list[1, 3].set_ylabel('')
ax_list[1, 4].set_ylabel('')

plt.tight_layout(w_pad=0.4)
#plt.tight_layout(h_pad=0.1)
#plt.show()

#save figures
save_path = '../Figure/' 
#plt.savefig(save_path + 'benchmark_sim1.pdf', bbox_inches='tight', dpi=300)
# Out:
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ...

# %% [markdown]
# # Ground truth

# %%
# add ground truth
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
plt.rcParams['figure.figsize'] = (2.5,2.5)
plt.rcParams['font.size'] = 15
plt.rcParams['font.sans-serif'] = 'Arial'

dataset = 'Simulation1'
path = '../result/'
adata = sc.read_h5ad(path + dataset + '/' + 'adata_all_simulation1.h5ad')

adata.obs['ground_truth'] = 1*np.array(adata.obsm['spfac'][:,0] + 2*adata.obsm['spfac'][:,1] + 3*adata.obsm['spfac'][:,2] + 4*adata.obsm['spfac'][:,3])
adata.obs['annotation'] = adata.obs['ground_truth']
adata.obs['annotation'].replace({1.0:'factor1',
                                   2.0:'factor2',
                                   3.0:'factor3',
                                   4.0:'factor4',
                                   0.0:'backgr'  #'backgr' means background.
                                              }, inplace=True)

list_ = ['factor1','factor2','factor3','factor4','backgr']
adata.obs['annotation']  = pd.Categorical(adata.obs['annotation'], 
                      categories=list_,
                      ordered=True)

sc.pl.embedding(adata, basis='spatial', title='Ground truth', color='annotation', s=70, show=False)
plt.xlabel('')
plt.ylabel('')

#save figures
save_path = '../Figure/' 
#plt.savefig(save_path + 'ground_truth.pdf', bbox_inches='tight', dpi=300)
# Out:
# /home/yahui/anaconda3/envs/STGAT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Quantitative evaluation on single simulation data

# %%
import pandas as pd
res = pd.read_csv('../result/Simulation/evalution_simulation1.csv', index_col=0)
res.index = res.index.where(res.index != 'MOFA', 'MOFA+')

res_stack = res.stack().reset_index()
#res_stack
res_stack.columns=['Method', 'Metric', 'value']
res_stack.set_index('Method')

# plotting
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,3)
plt.rcParams['font.size'] = 15
plt.rcParams['font.sans-serif'] = 'Arial'

#ax = sns.boxplot(data=res_stack, x='Method', y='value', linewidth=0.5, showfliers=False)

res.T.plot(kind='bar', width=0.8)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)
plt.xticks(rotation=45)
plt.ylabel('Value')

path = '../Figure/'
#plt.savefig(path +  'benchmark_sim1.jpg', bbox_inches='tight', dpi=300)

# %% [markdown]
# # Quantitative evaluation on 5 simulation data

# %%
## Plot quantitative results
import pandas as pd
res_all = pd.read_csv('../result/evalution_simulation_all.csv', index_col=0)
res_all.index = res_all.index.where(res_all.index != 'MOFA', 'MOFA+')
res_all_stack = res_all.stack().reset_index()
res_all_stack
res_all_stack.columns=['Method', 'Metric', 'value']
res_all_stack.set_index('Method')

# plotting
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,3)
plt.rcParams['font.size'] = 15
plt.rcParams['font.sans-serif'] = 'Arial'

ax = sns.boxplot(data=res_all_stack, x='Metric', y='value', hue='Method', linewidth=0.5, showfliers=False)

plt.xticks(rotation=45)
#plt.yticks(size=50)
ax.set_xlabel('')
ax.set_ylabel('Value')
ax.set_title('')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)

path = '../Figure/'
plt.savefig(path +  'benchmark_sim_all.jpg', bbox_inches='tight', dpi=300)
